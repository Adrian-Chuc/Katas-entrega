# %% [markdown]
# ## FECHA DE HOY:

# %%
from datetime import date
print("El día de hoy es: " + str(date.today()))
# Out:
# El día de hoy es: 2022-02-14

# %% [markdown]
# ## CONVERSOR DE PARSECS A AÑOS LUZ

# %%
parsecs= float(input('Cuantos persec quieres convertir?:'))
añosluz= (3.26156 *parsecs)
print(str(parsecs) + " parsec, son " + str(añosluz) + " años luz")
# Out:
# 8.0 parsec, son 26.09248 años luz
